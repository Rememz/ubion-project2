# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./데이터자료/증가율데이터수정(완).csv', encoding='CP949',index_col=0)
df.reset_index(inplace=True)

# %%
df_label = df[['index','회사명', '거래소코드', '회계년도', '상장일', '상장폐지일', '소속코드']]

# %%
df_label= df_label[df_label['소속코드']==4]
df_label= df_label.groupby('회사명')['index'].apply(list)

# %%
df_label = pd.DataFrame(df_label)

# %%
df_label["index"]["(주)나노트로닉스"][-1]
# Out:
# 236

# %%
for j in df_label.index:
    for i in df.index:
        if df_label["index"][j][-1] == i:
            df.loc[i,'label'] = 1
df['label'] = df["label"].fillna(0)

# %%
df21_1 = pd.read_csv('./데이터자료/21상폐기업.csv', encoding='CP949')
df21_2 = pd.read_csv('./데이터자료/21년상폐개별.csv', encoding='CP949')

# %%
df["회계년도"] = pd.to_datetime(df["회계년도"])
df21_1["회계년도"] = pd.to_datetime(df21_1["회계년도"], format='%y-%b')
df21_2["회계년도"] = pd.to_datetime(df21_1["회계년도"], format='%y-%b')
df21_2.drop(['회사명.1'], axis=1, inplace=True)

# %%
df21_1=df21_1[['회사명', '거래소코드', '회계년도', '상장일', '상장폐지일', '산업명', '소속코드', '[제조]매출액증가율',
       '[제조]유형자산증가율', '[제조]비유동자산증가율', '[제조]총자본증가율', '[제조]자기자본증가율',
       '[제조]유동자산증가율', '[제조]순이익증가율', '[제조]재고자산증가율', '[제조]매출액총이익률',
       '[제조]매출액순이익률', '[제조]총자본사업이익률', '[제조]총자본순이익률', '[제조]자기자본순이익률',
       '[제조]1주당순이익', '[제조]1주당매출액', '[제조]총자본회전률', '[제조]자기자본회전률', '[제조]비유동자산회전률',
       '[제조]재고자산회전률', '[제조]매출채권회전률', '[제조]매입채무회전률', '[제조]매입채무회전기간',
       '[제조]재고자산회전기간', '[제조]매출채권회전기간', '[제조]1회전기간', '[제조]운전자본회전률',
       '[제조]순운전자본회전률', '[제조]유동자산회전률', '[제조]당좌자산회전률', '[제조]유동비율', '[제조]당좌비율',
       '[제조]현금비율', '[제조]부채비율', '[제조]순운전자본비율', '[제조]자기자본배율', '[제조]비유동비율',
       '[제조]유동자산구성비율', '[제조]자기자본구성비율', '[제조]부가가치', '[제조]총자본투자효율', '[제조]설비투자효율',
       '[제조]기계투자효율', '[제조]부가가치율', '[제조]노동소득분배율', '[제조]자본분배율', '[제조]이윤분배율',
       '[제조]유형자산회전율', '[제조]이자보상배율(이자비용)', 'label']]

# %%
df_all = pd.concat([df,df21_1])
df_all = df_all.reset_index(drop='index')

# %%
df_all.drop(0,inplace=True)

# %%
df_all.drop('index',axis=1, inplace=True)

# %%
df_all
# Out:
#              회사명  거래소코드       회계년도         상장일       상장폐지일  \
# 1       (주)CMG제약  58820 2012-12-01  2001/08/31         NaN
# 2       (주)CMG제약  58820 2013-12-01  2001/08/31         NaN
# 3       (주)CMG제약  58820 2014-12-01  2001/08/31         NaN
# 4       (주)CMG제약  58820 2015-12-01  2001/08/31         NaN
# 5       (주)CMG제약  58820 2016-12-01  2001/08/31         NaN
# ...          ...    ...        ...         ...         ...
# 10689  에이아이비트(주)  39230 2016-12-01  2000-06-22  2021-10-06
# 10690  에이아이비트(주)  39230 2017-12-01  2000-06-22  2021-10-06
# 10691  에이아이비트(주)  39230 2018-12-01  2000-06-22  2021-10-06
# 10692  에이아이비트(주)  39230 2019-12-01  2000-06-22  2021-10-06
# 10693  에이아이비트(주)  39230 2020-12-01  2000-06-22  2021-10-06
#
#                                              산업명  소속코드  [제조]매출액증가율  \
# 1                               의료용 물질 및 의약품 제조업     5       -8.43
# 2                               의료용 물질 및 의약품 제조업     5       25.51
# ...

# %%
df_all.to_csv("label(완).csv",encoding='cp949')

# %%
df_all[df_all["회사명"]=="(주)팍스넷"]
# Out:
#           회사명  거래소코드       회계년도         상장일       상장폐지일             산업명  소속코드  \
# 10628  (주)팍스넷  38160 2016-12-01  2016-08-01  2021-08-23      기타 정보 서비스업     4
# 10629  (주)팍스넷  38160 2017-12-01  2016-08-01  2021-08-23      기타 정보 서비스업     4
# 10630  (주)팍스넷  38160 2018-12-01  2016-08-01  2021-08-23      기타 정보 서비스업     4
# 10631  (주)팍스넷  38160 2019-12-01  2016-08-01  2021-08-23      기타 정보 서비스업     4
# 10632  (주)팍스넷  38160 2020-12-01  2016-08-01  2021-08-23      기타 정보 서비스업     4
#
#        [제조]매출액증가율  [제조]유형자산증가율  [제조]비유동자산증가율  ...  [제조]총자본투자효율  [제조]설비투자효율  \
# 10628        8.04       -16.63         40.58  ...        21.02     2710.81
# 10629      -17.67       -25.80        123.78  ...        15.69     2851.35
# 10630       -2.35      2785.49         43.23  ...         6.45       51.37
# 10631      -40.28        64.14         25.38  ...       -17.83     -209.51
# 10632       -3.90       -55.28        -43.21  ...       -41.99     -239.45
#
# ...
