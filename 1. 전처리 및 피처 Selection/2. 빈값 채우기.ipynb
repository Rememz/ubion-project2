# %%
import pandas as pd
import numpy as np

# %%
# 연결데이터 , 개별데이터 불러오기
df_con = pd.read_csv("./데이터자료/1. 상장폐지종목 정리끝.csv",index_col=0)
df_invis = pd.read_csv("./데이터자료/1. 코스닥 기업 개별재무제표.csv",encoding='cp949')

# %%
df_con.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10450 entries, 0 to 10449
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   회사명                       10450 non-null  object
#  1   거래소코드                     10450 non-null  int64
#  2   회계년도                      10450 non-null  object
#  3   상장일                       10450 non-null  object
#  4   상장폐지일                     860 non-null    object
#  5   소속코드                      10450 non-null  int64
#  6   산업명                       10450 non-null  object
#  7   [제조]총자본증가율(IFRS연결)        7906 non-null   float64
#  8   [제조]유형자산증가율(IFRS연결)       7906 non-null   float64
#  9   [제조]비유동자산증가율(IFRS연결)      7906 non-null   float64
#  10  [제조]유동자산증가율(IFRS연결)       7906 non-null   float64
#  11  [제조]재고자산증가율(IFRS연결)       7906 non-null   float64
#  12  [제조]자기자본증가율(IFRS연결)       7906 non-null   float64
#  13  [제조]매출액증가율(IFRS연결)        7906 non-null   float64
#  14  [제조]순이익증가율(IFRS연결)        7906 non-null   float64
#  15  [제조]매출액총이익률(IFRS연결)       7906 non-null   float64
#  16  [제조]매출액순이익률(IFRS연결)       7906 non-null   float64
#  17  [제조]자기자본순이익률(IFRS연결)      7906 non-null   float64
#  18  [제조]총자본사업이익률(IFRS연결)      7906 non-null   float64
#  19  [제조]총자본순이익률(IFRS연결)       7906 non-null   float64
#  20  [제조]1주당매출액(IFRS연결)        7906 non-null   float64
#  21  [제조]1주당순이익(IFRS연결)        7906 non-null   float64
#  22  [제조]유동비율(IFRS연결)          7906 non-null   float64
#  23  [제조]당좌비율(IFRS연결)          7906 non-null   float64
#  24  [제조]현금비율(IFRS연결)          7906 non-null   float64
#  25  [제조]순운전자본비율(IFRS연결)       7906 non-null   float64
#  26  [제조]부채비율(IFRS연결)          7906 non-null   float64
#  27  [제조]이자보상배율(이자비용)(IFRS연결)  7906 non-null   float64
#  28  [제조]비유동비율(IFRS연결)         7906 non-null   float64
#  29  [제조]유동자산구성비율(IFRS연결)      7906 non-null   float64
#  30  [제조]자기자본구성비율(IFRS연결)      7906 non-null   float64
#  31  [제조]자기자본배율(IFRS연결)        7906 non-null   float64
#  32  [제조]총자본회전률(IFRS연결)        7906 non-null   float64
#  33  [제조]자기자본회전률(IFRS연결)       7906 non-null   float64
#  34  [제조]비유동자산회전률(IFRS연결)      7906 non-null   float64
#  35  [제조]재고자산회전률(IFRS연결)       7906 non-null   float64
#  36  [제조]매출채권회전률(IFRS연결)       7906 non-null   float64
#  37  [제조]매입채무회전률(IFRS연결)       7906 non-null   float64
#  38  [제조]매입채무회전기간(IFRS연결)      7906 non-null   float64
#  39  [제조]재고자산회전기간(IFRS연결)      7906 non-null   float64
#  40  [제조]매출채권회전기간(IFRS연결)      7906 non-null   float64
#  41  [제조]1회전기간(IFRS연결)         7906 non-null   float64
#  42  [제조]운전자본회전률(IFRS연결)       7906 non-null   float64
#  43  [제조]순운전자본회전률(IFRS연결)      7906 non-null   float64
#  44  [제조]유형자산회전율(IFRS연결)       7906 non-null   float64
#  45  [제조]유동자산회전률(IFRS연결)       7906 non-null   float64
#  46  [제조]당좌자산회전률(IFRS연결)       7906 non-null   float64
#  47  [제조]부가가치(IFRS연결)          7906 non-null   float64
#  48  [제조]총자본투자효율(IFRS연결)       7906 non-null   float64
#  49  [제조]설비투자효율(IFRS연결)        7906 non-null   float64
#  50  [제조]기계투자효율(IFRS연결)        7906 non-null   float64
#  51  [제조]부가가치율(IFRS연결)         7906 non-null   float64
#  52  [제조]노동소득분배율(IFRS연결)       7906 non-null   float64
#  53  [제조]자본분배율(IFRS연결)         7906 non-null   float64
#  54  [제조]이윤분배율(IFRS연결)         7906 non-null   float64
#  55  상장폐지사유                    45 non-null     object
#  56  회계월                       10450 non-null  int64
#  57  상장년도                      10450 non-null  int64
#  58  회계년                       10450 non-null  int64
#  59  연차                        10450 non-null  int64
# dtypes: float64(48), int64(6), object(6)
# memory usage: 4.9+ MB

# %%
df_con[:20]
# Out:
#          회사명  거래소코드        회계년도         상장일 상장폐지일  소속코드                 산업명  \
# 0   (주)CMG제약  58820  2011-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 1   (주)CMG제약  58820  2012-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 2   (주)CMG제약  58820  2013-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 3   (주)CMG제약  58820  2014-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 4   (주)CMG제약  58820  2015-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 5   (주)CMG제약  58820  2016-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 6   (주)CMG제약  58820  2017-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 7   (주)CMG제약  58820  2018-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 8   (주)CMG제약  58820  2019-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 9   (주)CMG제약  58820  2020-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 10   (주)ES큐브  50120  2011-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 11   (주)ES큐브  50120  2012-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 12   (주)ES큐브  50120  2013-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 13   (주)ES큐브  50120  2014-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 14   (주)ES큐브  50120  2015-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 15   (주)ES큐브  50120  2016-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 16   (주)ES큐브  50120  2017-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 17   (주)ES큐브  50120  2018-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 18   (주)ES큐브  50120  2019-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 19   (주)ES큐브  50120  2020-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
#
#     [제조]총자본증가율(IFRS연결)  [제조]유형자산증가율(IFRS연결)  [제조]비유동자산증가율(IFRS연결)  ...  \
# 0                 1.98                -5.90                -12.89  ...
# 1               109.15                -4.12                -16.43  ...
# 2                -2.09                16.09                 77.05  ...
# 3                 3.86                74.30                 68.15  ...
# 4                -2.64                -5.37                  1.66  ...
# 5                96.31                -5.14                  6.43  ...
# 6                -1.27                -4.28                -12.01  ...
# 7                 4.39                 6.71                 16.47  ...
# 8                68.07                39.67                 26.20  ...
# 9                  NaN                  NaN                   NaN  ...
# 10                0.00                 0.00                  0.00  ...
# 11                0.00                 0.00                  0.00  ...
# 12                1.85               -31.56                -62.76  ...
# 13               20.10                 5.59                 18.41  ...
# 14               -1.75               -14.40                 38.88  ...
# 15               89.08               258.91                275.90  ...
# 16                0.69                64.55                  1.06  ...
# 17                6.17                30.79                 22.82  ...
# 18              312.66                14.02                 55.75  ...
# 19               54.08                69.21                274.24  ...
#
#     [제조]기계투자효율(IFRS연결)  [제조]부가가치율(IFRS연결)  [제조]노동소득분배율(IFRS연결)  \
# 0               128.51              19.56                89.82
# 1                10.67               1.66              1749.87
# 2               289.40              34.29                71.28
# 3               132.06              31.04                79.30
# 4                90.92              15.96               144.10
# 5               273.60              31.90                63.53
# 6               389.08              33.01                64.09
# 7               478.91              33.79                67.33
# 8               438.05              32.47                72.60
# 9                  NaN                NaN                  NaN
# 10             1125.26              22.56               120.20
# 11             2009.57              32.14                86.11
# 12              225.06               2.45              1052.79
# 13              857.87              12.98                82.73
# 14              575.47               6.33               197.05
# 15            11735.41              78.38                16.17
# 16             1606.97              20.96                55.49
# 17              278.71               3.45               390.13
# 18             -148.46              -1.28                 0.00
# 19             1164.79               4.67               212.62
#
#     [제조]자본분배율(IFRS연결)  [제조]이윤분배율(IFRS연결)  상장폐지사유  회계월  상장년도   회계년  연차
# 0               10.18             -43.44     NaN   12  2001  2011  10
# 1            -1649.87           -2473.07     NaN   12  2001  2012  11
# 2               28.72               4.23     NaN   12  2001  2013  12
# 3               20.70               2.24     NaN   12  2001  2014  13
# 4              -44.10             -84.58     NaN   12  2001  2015  14
# 5               36.47              16.43     NaN   12  2001  2016  15
# 6               35.91              20.68     NaN   12  2001  2017  16
# 7               32.67              36.00     NaN   12  2001  2018  17
# 8               27.40              16.03     NaN   12  2001  2019  18
# 9                 NaN                NaN     NaN   12  2001  2020  19
# 10             -20.20             -39.82     NaN   12  2002  2011   9
# 11              13.89              -2.00     NaN   12  2002  2012  10
# 12            -952.79           -1147.24     NaN   12  2002  2013  11
# 13              17.27             -10.66     NaN   12  2002  2014  12
# 14             -97.05             -86.40     NaN   12  2002  2015  13
# 15              83.83              80.15     NaN   12  2002  2016  14
# 16              44.51              23.19     NaN   12  2002  2017  15
# 17            -290.13            -525.20     NaN   12  2002  2018  16
# 18               0.00               0.00     NaN   12  2002  2019  17
# 19            -112.62            -671.19     NaN   12  2002  2020  18
#
# [20 rows x 60 columns]

# %%
df_invis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14347 entries, 0 to 14346
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   회사명                     14347 non-null  object
#  1   거래소코드                   14347 non-null  int64
#  2   회계년도                    14347 non-null  object
#  3   상장일                     14347 non-null  object
#  4   상장폐지일                   1534 non-null   object
#  5   소속코드                    14347 non-null  int64
#  6   산업명                     14347 non-null  object
#  7   [제조]총자본증가율(IFRS)        12300 non-null  float64
#  8   [제조]유형자산증가율(IFRS)       12300 non-null  float64
#  9   [제조]비유동자산증가율(IFRS)      12300 non-null  float64
#  10  [제조]유동자산증가율(IFRS)       12300 non-null  float64
#  11  [제조]재고자산증가율(IFRS)       12300 non-null  float64
#  12  [제조]자기자본증가율(IFRS)       12300 non-null  float64
#  13  [제조]매출액증가율(IFRS)        12300 non-null  float64
#  14  [제조]순이익증가율(IFRS)        12300 non-null  float64
#  15  [제조]매출액총이익률(IFRS)       12300 non-null  float64
#  16  [제조]매출액순이익률(IFRS)       12300 non-null  float64
#  17  [제조]자기자본순이익률(IFRS)      12300 non-null  float64
#  18  [제조]총자본사업이익률(IFRS)      12300 non-null  float64
#  19  [제조]총자본순이익률(IFRS)       12300 non-null  float64
#  20  [제조]1주당매출액(IFRS)        12300 non-null  float64
#  21  [제조]1주당순이익(IFRS)        12300 non-null  float64
#  22  [제조]유동비율(IFRS)          12300 non-null  float64
#  23  [제조]당좌비율(IFRS)          12300 non-null  float64
#  24  [제조]현금비율(IFRS)          12300 non-null  float64
#  25  [제조]순운전자본비율(IFRS)       12300 non-null  float64
#  26  [제조]부채비율(IFRS)          12300 non-null  float64
#  27  [제조]이자보상배율(이자비용)(IFRS)  12300 non-null  float64
#  28  [제조]비유동비율(IFRS)         12300 non-null  float64
#  29  [제조]유동자산구성비율(IFRS)      12300 non-null  float64
#  30  [제조]자기자본구성비율(IFRS)      12300 non-null  float64
#  31  [제조]자기자본배율(IFRS)        12300 non-null  float64
#  32  [제조]총자본회전률(IFRS)        12300 non-null  float64
#  33  [제조]자기자본회전률(IFRS)       12300 non-null  float64
#  34  [제조]비유동자산회전률(IFRS)      12300 non-null  float64
#  35  [제조]재고자산회전률(IFRS)       12300 non-null  float64
#  36  [제조]매출채권회전률(IFRS)       12300 non-null  float64
#  37  [제조]매입채무회전률(IFRS)       12300 non-null  float64
#  38  [제조]매입채무회전기간(IFRS)      12300 non-null  float64
#  39  [제조]재고자산회전기간(IFRS)      12300 non-null  float64
#  40  [제조]매출채권회전기간(IFRS)      12300 non-null  float64
#  41  [제조]1회전기간(IFRS)         12300 non-null  float64
#  42  [제조]운전자본회전률(IFRS)       12300 non-null  float64
#  43  [제조]순운전자본회전률(IFRS)      12300 non-null  float64
#  44  [제조]유형자산회전율(IFRS)       12300 non-null  float64
#  45  [제조]유동자산회전률(IFRS)       12300 non-null  float64
#  46  [제조]당좌자산회전률(IFRS)       12300 non-null  float64
#  47  [제조]부가가치(IFRS)          12299 non-null  float64
#  48  [제조]총자본투자효율(IFRS)       12299 non-null  float64
#  49  [제조]설비투자효율(IFRS)        12299 non-null  float64
#  50  [제조]기계투자효율(IFRS)        12299 non-null  float64
#  51  [제조]부가가치율(IFRS)         12299 non-null  float64
#  52  [제조]노동소득분배율(IFRS)       12299 non-null  float64
#  53  [제조]자본분배율(IFRS)         12299 non-null  float64
#  54  [제조]이윤분배율(IFRS)         12299 non-null  float64
# dtypes: float64(48), int64(2), object(5)
# memory usage: 6.0+ MB

# %%
df_invis[:20]
# Out:
#          회사명  거래소코드     회계년도         상장일 상장폐지일  소속코드                 산업명  \
# 0   (주)CMG제약  58820  2011/12  2001/08/31   NaN     5    의료용 물질 및 의약품 제조업
# 1   (주)CMG제약  58820  2012/12  2001/08/31   NaN     5    의료용 물질 및 의약품 제조업
# 2   (주)CMG제약  58820  2013/12  2001/08/31   NaN     5    의료용 물질 및 의약품 제조업
# 3   (주)CMG제약  58820  2014/12  2001/08/31   NaN     5    의료용 물질 및 의약품 제조업
# 4   (주)CMG제약  58820  2015/12  2001/08/31   NaN     5    의료용 물질 및 의약품 제조업
# 5   (주)CMG제약  58820  2016/12  2001/08/31   NaN     5    의료용 물질 및 의약품 제조업
# 6   (주)CMG제약  58820  2017/12  2001/08/31   NaN     5    의료용 물질 및 의약품 제조업
# 7   (주)CMG제약  58820  2018/12  2001/08/31   NaN     5    의료용 물질 및 의약품 제조업
# 8   (주)CMG제약  58820  2019/12  2001/08/31   NaN     5    의료용 물질 및 의약품 제조업
# 9   (주)CMG제약  58820  2020/12  2001/08/31   NaN     5    의료용 물질 및 의약품 제조업
# 10   (주)ES큐브  50120  2011/12  2002/04/25   NaN     5         도매 및 상품 중개업
# 11   (주)ES큐브  50120  2012/12  2002/04/25   NaN     5         도매 및 상품 중개업
# 12   (주)ES큐브  50120  2013/12  2002/04/25   NaN     5         도매 및 상품 중개업
# 13   (주)ES큐브  50120  2014/12  2002/04/25   NaN     5         도매 및 상품 중개업
# 14   (주)ES큐브  50120  2015/12  2002/04/25   NaN     5         도매 및 상품 중개업
# 15   (주)ES큐브  50120  2016/12  2002/04/25   NaN     5         도매 및 상품 중개업
# 16   (주)ES큐브  50120  2017/12  2002/04/25   NaN     5         도매 및 상품 중개업
# 17   (주)ES큐브  50120  2018/12  2002/04/25   NaN     5         도매 및 상품 중개업
# 18   (주)ES큐브  50120  2019/12  2002/04/25   NaN     5         도매 및 상품 중개업
# 19   (주)ES큐브  50120  2020/12  2002/04/25   NaN     5         도매 및 상품 중개업
#
#     [제조]총자본증가율(IFRS)  [제조]유형자산증가율(IFRS)  [제조]비유동자산증가율(IFRS)  ...  \
# 0               2.89              -6.44              -10.56  ...
# 1             106.87              -4.02              -19.28  ...
# 2              -1.80              16.63               78.54  ...
# 3               3.87              74.30               68.15  ...
# 4              -2.64              -5.37                1.66  ...
# 5              96.11              -5.14                6.43  ...
# 6              -1.27              -4.28              -12.01  ...
# 7               4.39               6.71               16.47  ...
# 8              68.07              39.67               26.20  ...
# 9               1.62              23.31               18.52  ...
# 10             -5.43             -11.82               22.79  ...
# 11             -1.23              -0.80                9.82  ...
# 12              6.34             -34.47              -48.39  ...
# 13             -5.46             -30.00               56.34  ...
# 14              4.92              -6.88                4.68  ...
# 15            121.67             683.64              148.93  ...
# 16              0.37              60.62               -1.61  ...
# 17              3.46              44.96               32.18  ...
# 18             25.43              -2.80               40.72  ...
# 19            -39.74             -94.76              -33.37  ...
#
#     [제조]유동자산회전률(IFRS)  [제조]당좌자산회전률(IFRS)  [제조]부가가치(IFRS)  [제조]총자본투자효율(IFRS)  \
# 0                1.25               1.56         3669.25              13.32
# 1                0.52               0.57          -88.04              -0.15
# 2                0.48               0.52         6952.08              12.42
# 3                0.68               0.80         7065.04              12.15
# 4                0.99               1.22         4316.80               7.63
# 5                0.63               0.71        10518.86               9.48
# 6                0.52               0.57        13710.01              12.51
# 7                0.61               0.68        16847.65              14.73
# 8                0.51               0.55        19033.25               9.90
# 9                0.43               0.47        17019.70               8.71
# 10               1.85               1.90         7961.63              17.60
# 11               2.57               2.63        11617.33              26.00
# 12               1.90               1.94        -5722.54             -12.05
# 13               1.38               1.40         1481.40               3.30
# 14               1.67               1.70         6263.14              13.29
# 15               1.06               1.07        20160.01              19.30
# 16               0.84               0.85         4476.07               4.27
# 17               0.85               0.86          177.01               0.16
# 18               1.07               1.09        -6558.67              -4.82
# 19               1.90               1.97       -23593.21             -28.77
#
#     [제조]설비투자효율(IFRS)  [제조]기계투자효율(IFRS)  [제조]부가가치율(IFRS)  [제조]노동소득분배율(IFRS)  \
# 0              38.11            137.59            20.67              84.78
# 1              -0.95             -3.53            -0.54               0.00
# 2              77.44            287.63            34.21              71.51
# 3              37.82            132.13            31.05              79.26
# 4              24.22             90.95            15.96             144.05
# 5              62.31            273.60            31.90              63.53
# 6              84.87            389.08            33.01              64.09
# 7             106.25            478.91            33.79              67.33
# 8             114.60            438.05            32.47              72.60
# 9             108.22            475.13            26.40              86.14
# 10            565.75        1105781.81            19.09             123.24
# 11            832.22        2361246.32            26.30              85.34
# 12           -625.54       -3076633.35           -12.49               0.00
# 13            231.32              0.00             3.98             210.16
# 14           1050.25              0.00            16.98              40.09
# 15            431.40              0.00            57.90              11.50
# 16             59.63              0.00            12.06              53.04
# 17              1.63              0.00             0.57            1403.03
# 18            -62.01              0.00           -22.99               0.00
# 19          -4259.32              0.00           -77.88               0.00
#
#     [제조]자본분배율(IFRS)  [제조]이윤분배율(IFRS)
# 0             15.22           -34.46
# 1              0.00             0.00
# 2             28.49             4.82
# 3             20.74             2.43
# 4            -44.05           -84.52
# 5             36.47            16.10
# 6             35.91            20.68
# 7             32.67            36.00
# 8             27.40            16.03
# 9             13.86             1.26
# 10           -23.24           -36.84
# 11            14.66             4.45
# 12             0.00             0.00
# 13          -110.16          -162.84
# 14            59.91            57.64
# 15            88.50            86.65
# 16            46.96            27.23
# 17         -1303.03         -2167.18
# 18             0.00             0.00
# 19             0.00             0.00
#
# [20 rows x 55 columns]

# %%
#컬럼명 일치를 위한 컬럼명 변경 
df_con.columns = df_con.columns.str.replace('연결','')
df_con.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '상장일', '상장폐지일', '소속코드', '산업명',
#        '[제조]총자본증가율(IFRS)', '[제조]유형자산증가율(IFRS)', '[제조]비유동자산증가율(IFRS)',
#        '[제조]유동자산증가율(IFRS)', '[제조]재고자산증가율(IFRS)', '[제조]자기자본증가율(IFRS)',
#        '[제조]매출액증가율(IFRS)', '[제조]순이익증가율(IFRS)', '[제조]매출액총이익률(IFRS)',
#        '[제조]매출액순이익률(IFRS)', '[제조]자기자본순이익률(IFRS)', '[제조]총자본사업이익률(IFRS)',
#        '[제조]총자본순이익률(IFRS)', '[제조]1주당매출액(IFRS)', '[제조]1주당순이익(IFRS)',
#        '[제조]유동비율(IFRS)', '[제조]당좌비율(IFRS)', '[제조]현금비율(IFRS)',
#        '[제조]순운전자본비율(IFRS)', '[제조]부채비율(IFRS)', '[제조]이자보상배율(이자비용)(IFRS)',
#        '[제조]비유동비율(IFRS)', '[제조]유동자산구성비율(IFRS)', '[제조]자기자본구성비율(IFRS)',
#        '[제조]자기자본배율(IFRS)', '[제조]총자본회전률(IFRS)', '[제조]자기자본회전률(IFRS)',
#        '[제조]비유동자산회전률(IFRS)', '[제조]재고자산회전률(IFRS)', '[제조]매출채권회전률(IFRS)',
#        '[제조]매입채무회전률(IFRS)', '[제조]매입채무회전기간(IFRS)', '[제조]재고자산회전기간(IFRS)',
#        '[제조]매출채권회전기간(IFRS)', '[제조]1회전기간(IFRS)', '[제조]운전자본회전률(IFRS)',
#        '[제조]순운전자본회전률(IFRS)', '[제조]유형자산회전율(IFRS)', '[제조]유동자산회전률(IFRS)',
#        '[제조]당좌자산회전률(IFRS)', '[제조]부가가치(IFRS)', '[제조]총자본투자효율(IFRS)',
#        '[제조]설비투자효율(IFRS)', '[제조]기계투자효율(IFRS)', '[제조]부가가치율(IFRS)',
#        '[제조]노동소득분배율(IFRS)', '[제조]자본분배율(IFRS)', '[제조]이윤분배율(IFRS)', '상장폐지사유',
#        '회계월', '상장년도', '회계년', '연차'],
#       dtype='object')

# %%
# 빈 값을 넣기 위한 list 생성
list = ['[제조]총자본증가율(IFRS)', '[제조]유형자산증가율(IFRS)', '[제조]비유동자산증가율(IFRS)',
       '[제조]유동자산증가율(IFRS)', '[제조]재고자산증가율(IFRS)', '[제조]자기자본증가율(IFRS)',
       '[제조]매출액증가율(IFRS)', '[제조]순이익증가율(IFRS)', '[제조]매출액총이익률(IFRS)',
       '[제조]매출액순이익률(IFRS)', '[제조]자기자본순이익률(IFRS)', '[제조]총자본사업이익률(IFRS)',
       '[제조]총자본순이익률(IFRS)', '[제조]1주당매출액(IFRS)', '[제조]1주당순이익(IFRS)',
       '[제조]유동비율(IFRS)', '[제조]당좌비율(IFRS)', '[제조]현금비율(IFRS)',
       '[제조]순운전자본비율(IFRS)', '[제조]부채비율(IFRS)', '[제조]이자보상배율(이자비용)(IFRS)',
       '[제조]비유동비율(IFRS)', '[제조]유동자산구성비율(IFRS)', '[제조]자기자본구성비율(IFRS)',
       '[제조]자기자본배율(IFRS)', '[제조]총자본회전률(IFRS)', '[제조]자기자본회전률(IFRS)',
       '[제조]비유동자산회전률(IFRS)', '[제조]재고자산회전률(IFRS)', '[제조]매출채권회전률(IFRS)',
       '[제조]매입채무회전률(IFRS)', '[제조]매입채무회전기간(IFRS)', '[제조]재고자산회전기간(IFRS)',
       '[제조]매출채권회전기간(IFRS)', '[제조]1회전기간(IFRS)', '[제조]운전자본회전률(IFRS)',
       '[제조]순운전자본회전률(IFRS)', '[제조]유형자산회전율(IFRS)', '[제조]유동자산회전률(IFRS)',
       '[제조]당좌자산회전률(IFRS)', '[제조]부가가치(IFRS)', '[제조]총자본투자효율(IFRS)',
       '[제조]설비투자효율(IFRS)', '[제조]기계투자효율(IFRS)', '[제조]부가가치율(IFRS)',
       '[제조]노동소득분배율(IFRS)', '[제조]자본분배율(IFRS)', '[제조]이윤분배율(IFRS)']

# %%
# 빈공간을 개별로 넣기 
for i in list:
    df_con[i] = df_con[i].fillna(df_invis[i])
    print(df_con[i])
# Out:
# 0          1.98
# 1        109.15
# 2         -2.09
# 3          3.86
# 4         -2.64
#           ...
# 10445     -2.26
# 10446      2.71
# 10447      2.47
# 10448     -3.60
# 10449      1.77
# Name: [제조]총자본증가율(IFRS), Length: 10450, dtype: float64
# 0        -5.90
# 1        -4.12
# 2        16.09
# 3        74.30
# 4        -5.37
#          ...
# 10445    -2.56
# 10446    -7.36
# 10447    -2.78
# 10448    -0.50
# 10449    11.95
# Name: [제조]유형자산증가율(IFRS), Length: 10450, dtype: float64
# 0       -12.89
# 1       -16.43
# 2        77.05
# 3        68.15
# 4         1.66
#          ...
# 10445    -1.88
# 10446    37.82
# 10447    -3.98
# 10448    10.54
# 10449    25.00
# Name: [제조]비유동자산증가율(IFRS), Length: 10450, dtype: float64
# 0         17.64
# 1        207.08
# 2        -18.89
# 3        -25.93
# 4         -7.17
#           ...
# 10445     -2.34
# 10446     -4.96
# 10447      4.51
# 10448     -7.71
# 10449     -6.33
# Name: [제조]유동자산증가율(IFRS), Length: 10450, dtype: float64
# 0         -1.43
# 1          7.73
# 2         56.29
# 3          6.37
# 4         11.04
#           ...
# 10445    -23.47
# 10446     -6.74
# 10447    -53.03
# 10448    125.60
# 10449    -38.43
# Name: [제조]재고자산증가율(IFRS), Length: 10450, dtype: float64
# 0        -2.02
# 1        75.17
# 2        55.10
# 3         0.01
# 4        -4.48
#          ...
# 10445     4.32
# 10446     4.34
# 10447     4.26
# 10448    -1.31
# 10449     0.61
# Name: [제조]자기자본증가율(IFRS), Length: 10450, dtype: float64
# 0        56.40
# 1        -8.43
# 2        25.51
# 3        11.52
# 4        18.85
#          ...
# 10445   -18.82
# 10446   -20.58
# 10447     1.96
# 10448    21.23
# 10449    -1.27
# Name: [제조]매출액증가율(IFRS), Length: 10450, dtype: float64
# 0         0.00
# 1         0.00
# 2         0.00
# 3       -46.64
# 4         0.00
#          ...
# 10445   -15.20
# 10446     4.42
# 10447    -7.14
# 10448   -48.56
# 10449    49.83
# Name: [제조]순이익증가율(IFRS), Length: 10450, dtype: float64
# 0        41.83
# 1        28.34
# 2        38.70
# 3        37.07
# 4        36.26
#          ...
# 10445     5.25
# 10446     6.70
# 10447     6.48
# 10448     5.33
# 10449     4.86
# Name: [제조]매출액총이익률(IFRS), Length: 10450, dtype: float64
# 0        -8.50
# 1       -40.97
# 2         1.45
# 3         0.69
# 4       -13.50
#          ...
# 10445     3.02
# 10446     3.97
# 10447     3.61
# 10448     1.53
# 10449     2.33
# Name: [제조]매출액순이익률(IFRS), Length: 10450, dtype: float64
# 0        -8.28
# 1       -26.84
# 2         0.74
# 3         0.32
# 4        -7.62
#          ...
# 10445     6.20
# 10446     6.21
# 10447     5.53
# 10448     2.80
# 10449     4.22
# Name: [제조]자기자본순이익률(IFRS), Length: 10450, dtype: float64
# 0        2.52
# 1       -9.65
# 2        2.81
# 3        1.25
# 4       -4.30
#          ...
# 10445    4.67
# 10446    4.92
# 10447    4.27
# 10448    4.02
# 10449    3.17
# Name: [제조]총자본사업이익률(IFRS), Length: 10450, dtype: float64
# 0        -5.58
# 1       -15.78
# 2         0.52
# 3         0.28
# 4        -6.37
#          ...
# 10445     4.75
# 10446     4.95
# 10447     4.48
# 10448     2.32
# 10449     3.51
# Name: [제조]총자본순이익률(IFRS), Length: 10450, dtype: float64
# 0          406.28
# 1          332.74
# 2          235.52
# 3          262.65
# 4          306.26
#            ...
# 10445    10691.06
# 10446     8491.03
# 10447     8657.64
# 10448    10495.64
# 10449    10362.49
# Name: [제조]1주당매출액(IFRS), Length: 10450, dtype: float64
# 0        -35.00
# 1       -138.00
# 2          4.16
# 3          1.82
# 4        -42.00
#           ...
# 10445    345.00
# 10446    360.00
# 10447    334.00
# 10448    172.00
# 10449    267.00
# Name: [제조]1주당순이익(IFRS), Length: 10450, dtype: float64
# 0        200.97
# 1        693.49
# 2        694.71
# 3        324.58
# 4        296.85
#           ...
# 10445    436.02
# 10446    425.26
# 10447    460.77
# 10448    492.33
# 10449    432.33
# Name: [제조]유동비율(IFRS), Length: 10450, dtype: float64
# 0        165.03
# 1        649.98
# 2        610.74
# 3        268.23
# 4        235.21
#           ...
# 10445    386.29
# 10446    377.67
# 10447    437.59
# 10448    431.79
# 10449    397.39
# Name: [제조]당좌비율(IFRS), Length: 10450, dtype: float64
# 0         15.10
# 1         68.81
# 2        394.63
# 3        101.24
# 4         29.00
#           ...
# 10445    129.58
# 10446    114.93
# 10447    111.53
# 10448     90.50
# 10449     64.20
# Name: [제조]현금비율(IFRS), Length: 10450, dtype: float64
# 0        28.23
# 1        70.60
# 2        58.50
# 3        33.72
# 4        30.82
#          ...
# 10445    63.26
# 10446    58.09
# 10447    60.65
# 10448    59.10
# 10449    52.47
# Name: [제조]순운전자본비율(IFRS), Length: 10450, dtype: float64
# 0        51.41
# 1        80.77
# 2        14.11
# 3        18.50
# 4        20.78
#          ...
# 10445    26.43
# 10446    24.45
# 10447    22.31
# 10448    19.47
# 10449    20.84
# Name: [제조]부채비율(IFRS), Length: 10450, dtype: float64
# 0          3.53
# 1         -7.75
# 2          0.70
# 3          3.60
# 4        -32.22
#           ...
# 10445    172.77
# 10446    208.21
# 10447    301.30
# 10448    131.90
# 10449     34.51
# Name: [제조]이자보상배율(이자비용)(IFRS), Length: 10450, dtype: float64
# 0        66.34
# 1        31.65
# 2        36.13
# 3        60.75
# 4        64.65
#          ...
# 10445    22.66
# 10446    29.93
# 10447    27.56
# 10448    30.87
# 10449    38.35
# Name: [제조]비유동비율(IFRS), Length: 10450, dtype: float64
# 0        56.18
# 1        82.49
# 2        68.34
# 3        48.74
# 4        46.47
#          ...
# 10445    82.08
# 10446    75.95
# 10447    77.47
# 10448    74.16
# 10449    68.26
# Name: [제조]유동자산구성비율(IFRS), Length: 10450, dtype: float64
# 0        66.05
# 1        55.32
# 2        87.63
# 3        84.39
# 4        82.80
#          ...
# 10445    79.10
# 10446    80.35
# 10447    81.76
# 10448    83.71
# 10449    82.75
# Name: [제조]자기자본구성비율(IFRS), Length: 10450, dtype: float64
# 0          82.55
# 1          95.69
# 2         113.12
# 3         113.13
# 4         106.02
#           ...
# 10445    1008.27
# 10446    1052.03
# 10447    1096.89
# 10448    1082.55
# 10449    1089.17
# Name: [제조]자기자본배율(IFRS), Length: 10450, dtype: float64
# 0        0.66
# 1        0.39
# 2        0.36
# 3        0.40
# 4        0.47
#          ...
# 10445    1.57
# 10446    1.25
# 10447    1.24
# 10448    1.51
# 10449    1.51
# Name: [제조]총자본회전률(IFRS), Length: 10450, dtype: float64
# 0        0.97
# 1        0.66
# 2        0.51
# 3        0.46
# 4        0.56
#          ...
# 10445    2.06
# 10446    1.56
# 10447    1.53
# 10448    1.83
# 10449    1.81
# Name: [제조]자기자본회전률(IFRS), Length: 10450, dtype: float64
# 0        1.38
# 1        1.48
# 2        1.47
# 3        0.96
# 4        0.90
#          ...
# 10445    8.80
# 10446    5.93
# 10447    5.33
# 10448    6.26
# 10449    5.23
# Name: [제조]비유동자산회전률(IFRS), Length: 10450, dtype: float64
# 0         6.42
# 1         5.71
# 2         5.39
# 3         4.77
# 4         5.22
#          ...
# 10445    14.75
# 10446    13.98
# 10447    20.10
# 10448    23.41
# 10449    20.65
# Name: [제조]재고자산회전률(IFRS), Length: 10450, dtype: float64
# 0        2.45
# 1        1.85
# 2        2.07
# 3        1.86
# 4        2.10
#          ...
# 10445    5.46
# 10446    5.62
# 10447    5.61
# 10448    6.57
# 10449    7.06
# Name: [제조]매출채권회전률(IFRS), Length: 10450, dtype: float64
# 0        11.95
# 1         7.83
# 2         6.20
# 3         5.27
# 4         5.66
#          ...
# 10445     8.17
# 10446     7.52
# 10447     7.94
# 10448    10.40
# 10449    10.74
# Name: [제조]매입채무회전률(IFRS), Length: 10450, dtype: float64
# 0        30.53
# 1        46.62
# 2        58.88
# 3        69.23
# 4        64.54
#          ...
# 10445    44.70
# 10446    48.55
# 10447    45.97
# 10448    35.09
# 10449    33.99
# Name: [제조]매입채무회전기간(IFRS), Length: 10450, dtype: float64
# 0        56.81
# 1        63.97
# 2        67.75
# 3        76.46
# 4        69.98
#          ...
# 10445    24.75
# 10446    26.11
# 10447    18.16
# 10448    15.59
# 10449    17.68
# Name: [제조]재고자산회전기간(IFRS), Length: 10450, dtype: float64
# 0        148.80
# 1        197.16
# 2        176.20
# 3        196.72
# 4        174.14
#           ...
# 10445     66.81
# 10446     64.90
# 10447     65.07
# 10448     55.54
# 10449     51.67
# Name: [제조]매출채권회전기간(IFRS), Length: 10450, dtype: float64
# 0        0.01
# 1        0.00
# 2        0.01
# 3        0.00
# 4        0.01
#          ...
# 10445    0.02
# 10446    0.02
# 10447    0.03
# 10448    0.03
# 10449    0.03
# Name: [제조]1회전기간(IFRS), Length: 10450, dtype: float64
# 0        0.00
# 1        0.00
# 2        0.79
# 3        0.74
# 4        0.60
#          ...
# 10445    0.08
# 10446    0.08
# 10447    0.06
# 10448    0.05
# 10449    0.06
# Name: [제조]운전자본회전률(IFRS), Length: 10450, dtype: float64
# 0        0.86
# 1        0.42
# 2        0.42
# 3        0.56
# 4        0.75
#          ...
# 10445    1.53
# 10446    1.28
# 10447    1.32
# 10448    1.65
# 10449    1.74
# Name: [제조]순운전자본회전률(IFRS), Length: 10450, dtype: float64
# 0         1.77
# 1         1.71
# 2         2.03
# 3         1.54
# 4         1.48
#          ...
# 10445    14.79
# 10446    12.36
# 10447    13.29
# 10448    16.38
# 10449    15.30
# Name: [제조]유형자산회전율(IFRS), Length: 10450, dtype: float64
# 0        1.25
# 1        0.52
# 2        0.48
# 3        0.68
# 4        0.99
#          ...
# 10445    1.92
# 10446    1.58
# 10447    1.62
# 10448    1.99
# 10449    2.12
# Name: [제조]유동자산회전률(IFRS), Length: 10450, dtype: float64
# 0        1.55
# 1        0.57
# 2        0.52
# 3        0.80
# 4        1.22
#          ...
# 10445    2.20
# 10446    1.78
# 10447    1.76
# 10448    2.18
# 10449    2.36
# Name: [제조]당좌자산회전률(IFRS), Length: 10450, dtype: float64
# 0         3472.17
# 1          269.31
# 2         6994.90
# 3         7061.34
# 4         4315.37
#            ...
# 10445    13728.30
# 10446    14659.03
# 10447    14287.12
# 10448    11012.82
# 10449    13033.30
# Name: [제조]부가가치(IFRS), Length: 10450, dtype: float64
# 0        12.72
# 1         0.47
# 2        12.51
# 3        12.16
# 4         7.63
#          ...
# 10445    10.92
# 10446    11.36
# 10447    10.80
# 10448     8.64
# 10449    10.04
# Name: [제조]총자본투자효율(IFRS), Length: 10450, dtype: float64
# 0         35.86
# 1          2.89
# 2         77.91
# 3         37.80
# 4         24.21
#           ...
# 10445    102.82
# 10446    118.51
# 10447    118.81
# 10448     92.04
# 10449     97.30
# Name: [제조]설비투자효율(IFRS), Length: 10450, dtype: float64
# 0         128.51
# 1          10.67
# 2         289.40
# 3         132.06
# 4          90.92
#           ...
# 10445    3801.25
# 10446    5704.66
# 10447    4046.12
# 10448    2603.45
# 10449    3777.94
# Name: [제조]기계투자효율(IFRS), Length: 10450, dtype: float64
# 0        19.56
# 1         1.66
# 2        34.29
# 3        31.04
# 4        15.96
#          ...
# 10445     6.86
# 10446     9.22
# 10447     8.82
# 10448     5.61
# 10449     6.72
# Name: [제조]부가가치율(IFRS), Length: 10450, dtype: float64
# 0          89.82
# 1        1749.87
# 2          71.28
# 3          79.30
# 4         144.10
#           ...
# 10445      44.46
# 10446      43.35
# 10447      46.23
# 10448      62.14
# 10449      56.12
# Name: [제조]노동소득분배율(IFRS), Length: 10450, dtype: float64
# 0          10.18
# 1       -1649.87
# 2          28.72
# 3          20.70
# 4         -44.10
#           ...
# 10445      55.54
# 10446      56.65
# 10447      53.77
# 10448      37.86
# 10449      43.88
# Name: [제조]자본분배율(IFRS), Length: 10450, dtype: float64
# 0         -43.44
# 1       -2473.07
# 2           4.23
# 3           2.24
# 4         -84.58
#           ...
# 10445      43.99
# 10446      43.02
# 10447      40.99
# 10448      27.35
# 10449      34.63
# Name: [제조]이윤분배율(IFRS), Length: 10450, dtype: float64

# %%
df_con.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10450 entries, 0 to 10449
# Data columns (total 60 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   회사명                     10450 non-null  object
#  1   거래소코드                   10450 non-null  int64
#  2   회계년도                    10450 non-null  object
#  3   상장일                     10450 non-null  object
#  4   상장폐지일                   860 non-null    object
#  5   소속코드                    10450 non-null  int64
#  6   산업명                     10450 non-null  object
#  7   [제조]총자본증가율(IFRS)        10061 non-null  float64
#  8   [제조]유형자산증가율(IFRS)       10061 non-null  float64
#  9   [제조]비유동자산증가율(IFRS)      10061 non-null  float64
#  10  [제조]유동자산증가율(IFRS)       10061 non-null  float64
#  11  [제조]재고자산증가율(IFRS)       10061 non-null  float64
#  12  [제조]자기자본증가율(IFRS)       10061 non-null  float64
#  13  [제조]매출액증가율(IFRS)        10061 non-null  float64
#  14  [제조]순이익증가율(IFRS)        10061 non-null  float64
#  15  [제조]매출액총이익률(IFRS)       10061 non-null  float64
#  16  [제조]매출액순이익률(IFRS)       10061 non-null  float64
#  17  [제조]자기자본순이익률(IFRS)      10061 non-null  float64
#  18  [제조]총자본사업이익률(IFRS)      10061 non-null  float64
#  19  [제조]총자본순이익률(IFRS)       10061 non-null  float64
#  20  [제조]1주당매출액(IFRS)        10061 non-null  float64
#  21  [제조]1주당순이익(IFRS)        10061 non-null  float64
#  22  [제조]유동비율(IFRS)          10061 non-null  float64
#  23  [제조]당좌비율(IFRS)          10061 non-null  float64
#  24  [제조]현금비율(IFRS)          10061 non-null  float64
#  25  [제조]순운전자본비율(IFRS)       10061 non-null  float64
#  26  [제조]부채비율(IFRS)          10061 non-null  float64
#  27  [제조]이자보상배율(이자비용)(IFRS)  10061 non-null  float64
#  28  [제조]비유동비율(IFRS)         10061 non-null  float64
#  29  [제조]유동자산구성비율(IFRS)      10061 non-null  float64
#  30  [제조]자기자본구성비율(IFRS)      10061 non-null  float64
#  31  [제조]자기자본배율(IFRS)        10061 non-null  float64
#  32  [제조]총자본회전률(IFRS)        10061 non-null  float64
#  33  [제조]자기자본회전률(IFRS)       10061 non-null  float64
#  34  [제조]비유동자산회전률(IFRS)      10061 non-null  float64
#  35  [제조]재고자산회전률(IFRS)       10061 non-null  float64
#  36  [제조]매출채권회전률(IFRS)       10061 non-null  float64
#  37  [제조]매입채무회전률(IFRS)       10061 non-null  float64
#  38  [제조]매입채무회전기간(IFRS)      10061 non-null  float64
#  39  [제조]재고자산회전기간(IFRS)      10061 non-null  float64
#  40  [제조]매출채권회전기간(IFRS)      10061 non-null  float64
#  41  [제조]1회전기간(IFRS)         10061 non-null  float64
#  42  [제조]운전자본회전률(IFRS)       10061 non-null  float64
#  43  [제조]순운전자본회전률(IFRS)      10061 non-null  float64
#  44  [제조]유형자산회전율(IFRS)       10061 non-null  float64
#  45  [제조]유동자산회전률(IFRS)       10061 non-null  float64
#  46  [제조]당좌자산회전률(IFRS)       10061 non-null  float64
#  47  [제조]부가가치(IFRS)          10061 non-null  float64
#  48  [제조]총자본투자효율(IFRS)       10061 non-null  float64
#  49  [제조]설비투자효율(IFRS)        10061 non-null  float64
#  50  [제조]기계투자효율(IFRS)        10061 non-null  float64
#  51  [제조]부가가치율(IFRS)         10061 non-null  float64
#  52  [제조]노동소득분배율(IFRS)       10061 non-null  float64
#  53  [제조]자본분배율(IFRS)         10061 non-null  float64
#  54  [제조]이윤분배율(IFRS)         10061 non-null  float64
#  55  상장폐지사유                  45 non-null     object
#  56  회계월                     10450 non-null  int64
#  57  상장년도                    10450 non-null  int64
#  58  회계년                     10450 non-null  int64
#  59  연차                      10450 non-null  int64
# dtypes: float64(48), int64(6), object(6)
# memory usage: 4.9+ MB

# %%
df_con[:20]
# Out:
#          회사명  거래소코드        회계년도         상장일 상장폐지일  소속코드                 산업명  \
# 0   (주)CMG제약  58820  2011-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 1   (주)CMG제약  58820  2012-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 2   (주)CMG제약  58820  2013-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 3   (주)CMG제약  58820  2014-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 4   (주)CMG제약  58820  2015-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 5   (주)CMG제약  58820  2016-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 6   (주)CMG제약  58820  2017-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 7   (주)CMG제약  58820  2018-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 8   (주)CMG제약  58820  2019-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 9   (주)CMG제약  58820  2020-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 10   (주)ES큐브  50120  2011-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 11   (주)ES큐브  50120  2012-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 12   (주)ES큐브  50120  2013-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 13   (주)ES큐브  50120  2014-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 14   (주)ES큐브  50120  2015-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 15   (주)ES큐브  50120  2016-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 16   (주)ES큐브  50120  2017-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 17   (주)ES큐브  50120  2018-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 18   (주)ES큐브  50120  2019-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
# 19   (주)ES큐브  50120  2020-12-01  2002-04-25   NaN     5         도매 및 상품 중개업
#
#     [제조]총자본증가율(IFRS)  [제조]유형자산증가율(IFRS)  [제조]비유동자산증가율(IFRS)  ...  \
# 0               1.98              -5.90              -12.89  ...
# 1             109.15              -4.12              -16.43  ...
# 2              -2.09              16.09               77.05  ...
# 3               3.86              74.30               68.15  ...
# 4              -2.64              -5.37                1.66  ...
# 5              96.31              -5.14                6.43  ...
# 6              -1.27              -4.28              -12.01  ...
# 7               4.39               6.71               16.47  ...
# 8              68.07              39.67               26.20  ...
# 9               1.62              23.31               18.52  ...
# 10              0.00               0.00                0.00  ...
# 11              0.00               0.00                0.00  ...
# 12              1.85             -31.56              -62.76  ...
# 13             20.10               5.59               18.41  ...
# 14             -1.75             -14.40               38.88  ...
# 15             89.08             258.91              275.90  ...
# 16              0.69              64.55                1.06  ...
# 17              6.17              30.79               22.82  ...
# 18            312.66              14.02               55.75  ...
# 19             54.08              69.21              274.24  ...
#
#     [제조]기계투자효율(IFRS)  [제조]부가가치율(IFRS)  [제조]노동소득분배율(IFRS)  [제조]자본분배율(IFRS)  \
# 0             128.51            19.56              89.82            10.18
# 1              10.67             1.66            1749.87         -1649.87
# 2             289.40            34.29              71.28            28.72
# 3             132.06            31.04              79.30            20.70
# 4              90.92            15.96             144.10           -44.10
# 5             273.60            31.90              63.53            36.47
# 6             389.08            33.01              64.09            35.91
# 7             478.91            33.79              67.33            32.67
# 8             438.05            32.47              72.60            27.40
# 9             475.13            26.40              86.14            13.86
# 10           1125.26            22.56             120.20           -20.20
# 11           2009.57            32.14              86.11            13.89
# 12            225.06             2.45            1052.79          -952.79
# 13            857.87            12.98              82.73            17.27
# 14            575.47             6.33             197.05           -97.05
# 15          11735.41            78.38              16.17            83.83
# 16           1606.97            20.96              55.49            44.51
# 17            278.71             3.45             390.13          -290.13
# 18           -148.46            -1.28               0.00             0.00
# 19           1164.79             4.67             212.62          -112.62
#
#     [제조]이윤분배율(IFRS)  상장폐지사유  회계월  상장년도   회계년  연차
# 0            -43.44     NaN   12  2001  2011  10
# 1          -2473.07     NaN   12  2001  2012  11
# 2              4.23     NaN   12  2001  2013  12
# 3              2.24     NaN   12  2001  2014  13
# 4            -84.58     NaN   12  2001  2015  14
# 5             16.43     NaN   12  2001  2016  15
# 6             20.68     NaN   12  2001  2017  16
# 7             36.00     NaN   12  2001  2018  17
# 8             16.03     NaN   12  2001  2019  18
# 9              1.26     NaN   12  2001  2020  19
# 10           -39.82     NaN   12  2002  2011   9
# 11            -2.00     NaN   12  2002  2012  10
# 12         -1147.24     NaN   12  2002  2013  11
# 13           -10.66     NaN   12  2002  2014  12
# 14           -86.40     NaN   12  2002  2015  13
# 15            80.15     NaN   12  2002  2016  14
# 16            23.19     NaN   12  2002  2017  15
# 17          -525.20     NaN   12  2002  2018  16
# 18             0.00     NaN   12  2002  2019  17
# 19          -671.19     NaN   12  2002  2020  18
#
# [20 rows x 60 columns]

# %%
# 개별재무제표가 없는 데이터의 인덱스를 추출해서 없애기
a= df_con[df_con["[제조]총자본증가율(IFRS)"].isnull()].index
df_con.drop(a,inplace=True)

# %%
df_con.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10061 entries, 0 to 10449
# Data columns (total 60 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   회사명                     10061 non-null  object
#  1   거래소코드                   10061 non-null  int64
#  2   회계년도                    10061 non-null  object
#  3   상장일                     10061 non-null  object
#  4   상장폐지일                   828 non-null    object
#  5   소속코드                    10061 non-null  int64
#  6   산업명                     10061 non-null  object
#  7   [제조]총자본증가율(IFRS)        10061 non-null  float64
#  8   [제조]유형자산증가율(IFRS)       10061 non-null  float64
#  9   [제조]비유동자산증가율(IFRS)      10061 non-null  float64
#  10  [제조]유동자산증가율(IFRS)       10061 non-null  float64
#  11  [제조]재고자산증가율(IFRS)       10061 non-null  float64
#  12  [제조]자기자본증가율(IFRS)       10061 non-null  float64
#  13  [제조]매출액증가율(IFRS)        10061 non-null  float64
#  14  [제조]순이익증가율(IFRS)        10061 non-null  float64
#  15  [제조]매출액총이익률(IFRS)       10061 non-null  float64
#  16  [제조]매출액순이익률(IFRS)       10061 non-null  float64
#  17  [제조]자기자본순이익률(IFRS)      10061 non-null  float64
#  18  [제조]총자본사업이익률(IFRS)      10061 non-null  float64
#  19  [제조]총자본순이익률(IFRS)       10061 non-null  float64
#  20  [제조]1주당매출액(IFRS)        10061 non-null  float64
#  21  [제조]1주당순이익(IFRS)        10061 non-null  float64
#  22  [제조]유동비율(IFRS)          10061 non-null  float64
#  23  [제조]당좌비율(IFRS)          10061 non-null  float64
#  24  [제조]현금비율(IFRS)          10061 non-null  float64
#  25  [제조]순운전자본비율(IFRS)       10061 non-null  float64
#  26  [제조]부채비율(IFRS)          10061 non-null  float64
#  27  [제조]이자보상배율(이자비용)(IFRS)  10061 non-null  float64
#  28  [제조]비유동비율(IFRS)         10061 non-null  float64
#  29  [제조]유동자산구성비율(IFRS)      10061 non-null  float64
#  30  [제조]자기자본구성비율(IFRS)      10061 non-null  float64
#  31  [제조]자기자본배율(IFRS)        10061 non-null  float64
#  32  [제조]총자본회전률(IFRS)        10061 non-null  float64
#  33  [제조]자기자본회전률(IFRS)       10061 non-null  float64
#  34  [제조]비유동자산회전률(IFRS)      10061 non-null  float64
#  35  [제조]재고자산회전률(IFRS)       10061 non-null  float64
#  36  [제조]매출채권회전률(IFRS)       10061 non-null  float64
#  37  [제조]매입채무회전률(IFRS)       10061 non-null  float64
#  38  [제조]매입채무회전기간(IFRS)      10061 non-null  float64
#  39  [제조]재고자산회전기간(IFRS)      10061 non-null  float64
#  40  [제조]매출채권회전기간(IFRS)      10061 non-null  float64
#  41  [제조]1회전기간(IFRS)         10061 non-null  float64
#  42  [제조]운전자본회전률(IFRS)       10061 non-null  float64
#  43  [제조]순운전자본회전률(IFRS)      10061 non-null  float64
#  44  [제조]유형자산회전율(IFRS)       10061 non-null  float64
#  45  [제조]유동자산회전률(IFRS)       10061 non-null  float64
#  46  [제조]당좌자산회전률(IFRS)       10061 non-null  float64
#  47  [제조]부가가치(IFRS)          10061 non-null  float64
#  48  [제조]총자본투자효율(IFRS)       10061 non-null  float64
#  49  [제조]설비투자효율(IFRS)        10061 non-null  float64
#  50  [제조]기계투자효율(IFRS)        10061 non-null  float64
#  51  [제조]부가가치율(IFRS)         10061 non-null  float64
#  52  [제조]노동소득분배율(IFRS)       10061 non-null  float64
#  53  [제조]자본분배율(IFRS)         10061 non-null  float64
#  54  [제조]이윤분배율(IFRS)         10061 non-null  float64
#  55  상장폐지사유                  45 non-null     object
#  56  회계월                     10061 non-null  int64
#  57  상장년도                    10061 non-null  int64
#  58  회계년                     10061 non-null  int64
#  59  연차                      10061 non-null  int64
# dtypes: float64(48), int64(6), object(6)
# memory usage: 4.7+ MB

# %%
a = df_con.columns[9]
a
# Out:
# '[제조]비유동자산증가율(IFRS)'

# %%
a[4:]
# Out:
# '비유동자산증가율(IFRS)'

# %%
# 추가 다른 컬럼에서 결측치가 있는 데이터 삭제 
b  = df_con[df_con["[제조]이윤분배율(IFRS)"].isnull()].index
df_con.drop(b, inplace=True)

# %%
# 인덱스 초기화
df_con.reset_index(drop='index', inplace=True)

# %%
# 상장폐지일이 존재하면서 소속코드가 5인 데이터들의 상장폐지 일 내용 삭제
a = df_con[~df_con["상장폐지일"].isnull()]
b = a[a["소속코드"] ==5].index
b
# Out:
# Int64Index([ 661,  662, 2201, 2202, 2203, 2204, 2205, 2206, 3790, 3791, 3792,
#             3793, 3794, 3795, 3796, 3797, 5455, 5456, 5457, 5458, 5459, 5460,
#             6596, 6597, 6598, 6599, 6600, 6601, 6602, 6603, 8601, 8602, 8603,
#             8604, 8605, 8606, 8607, 8608, 8609, 9694, 9695, 9696, 9697, 9698,
#             9699],
#            dtype='int64')

# %%
# replace로 대체
for i in b:
    df_con["상장폐지일"] = df_con["상장폐지일"].replace(df_con.loc[i, "상장폐지일"], np.NAN)

# %%
# 대체 확인
c = df_con[~df_con["상장폐지일"].isnull()]
len(c[c["소속코드"] ==5]["회사명"].unique())
# Out:
# 0

# %%
print(len(df_con["회사명"].unique()))
print(len(df_con[df_con["소속코드"]==5]["회사명"].unique()))
print(len(df_con[df_con["소속코드"]==4]["회사명"].unique()))
# Out:
# 1439
# 1204
# 178

# %% [markdown]
# ## 총데이터 10061
# ## 총 기업수 1439 정상기업 1261 부도기업 178
# ## 우리의 부도기업 정의 에 따라 정상데이터 9083 부도데이터 178

# %% [markdown]
# ### 컬럼이름 간단하게 하기위해 수정
# ### 상장폐지 사유 컬럼 삭제

# %%
df_con.columns = df_con.columns.str.replace("제조",'')
df_con.columns = df_con.columns.str.replace('[','')
df_con.columns = df_con.columns.str.replace(']','')
df_con.columns = df_con.columns.str.replace('IFRS','')
df_con.columns = df_con.columns.str.replace("연결",'')
df_con.columns = df_con.columns.str.replace("(",'')
df_con.columns = df_con.columns.str.replace(")",'')
# Out:
# C:\Users\young\AppData\Local\Temp\ipykernel_4344\3807298736.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_con.columns = df_con.columns.str.replace('[','')
# C:\Users\young\AppData\Local\Temp\ipykernel_4344\3807298736.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_con.columns = df_con.columns.str.replace(']','')
# C:\Users\young\AppData\Local\Temp\ipykernel_4344\3807298736.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_con.columns = df_con.columns.str.replace("(",'')
# C:\Users\young\AppData\Local\Temp\ipykernel_4344\3807298736.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_con.columns = df_con.columns.str.replace(")",'')

# %%
df_con.drop('상장폐지사유',axis=1,inplace=True)

# %%
df_con
# Out:
#             회사명  거래소코드        회계년도         상장일 상장폐지일  소속코드  \
# 0      (주)CMG제약  58820  2011-12-01  2001-08-31   NaN     5
# 1      (주)CMG제약  58820  2012-12-01  2001-08-31   NaN     5
# 2      (주)CMG제약  58820  2013-12-01  2001-08-31   NaN     5
# 3      (주)CMG제약  58820  2014-12-01  2001-08-31   NaN     5
# 4      (주)CMG제약  58820  2015-12-01  2001-08-31   NaN     5
# ...         ...    ...         ...         ...   ...   ...
# 10056   흥구석유(주)  24060  2016-12-01  1994-12-07   NaN     5
# 10057   흥구석유(주)  24060  2017-12-01  1994-12-07   NaN     5
# 10058   흥구석유(주)  24060  2018-12-01  1994-12-07   NaN     5
# 10059   흥구석유(주)  24060  2019-12-01  1994-12-07   NaN     5
# 10060   흥구석유(주)  24060  2020-12-01  1994-12-07   NaN     5
#
#                       산업명  총자본증가율  유형자산증가율  비유동자산증가율  ...  설비투자효율   기계투자효율  \
# 0        의료용 물질 및 의약품 제조업    1.98    -5.90    -12.89  ...   35.86   128.51
# 1        의료용 물질 및 의약품 제조업  109.15    -4.12    -16.43  ...    2.89    10.67
# 2        의료용 물질 및 의약품 제조업   -2.09    16.09     77.05  ...   77.91   289.40
# 3        의료용 물질 및 의약품 제조업    3.86    74.30     68.15  ...   37.80   132.06
# 4        의료용 물질 및 의약품 제조업   -2.64    -5.37      1.66  ...   24.21    90.92
# ...                   ...     ...      ...       ...  ...     ...      ...
# 10056         도매 및 상품 중개업   -2.26    -2.56     -1.88  ...  102.82  3801.25
# 10057         도매 및 상품 중개업    2.71    -7.36     37.82  ...  118.51  5704.66
# 10058         도매 및 상품 중개업    2.47    -2.78     -3.98  ...  118.81  4046.12
# 10059         도매 및 상품 중개업   -3.60    -0.50     10.54  ...   92.04  2603.45
# 10060         도매 및 상품 중개업    1.77    11.95     25.00  ...   97.30  3777.94
#
#        부가가치율  노동소득분배율    자본분배율    이윤분배율  회계월  상장년도   회계년  연차
# 0      19.56    89.82    10.18   -43.44   12  2001  2011  10
# 1       1.66  1749.87 -1649.87 -2473.07   12  2001  2012  11
# 2      34.29    71.28    28.72     4.23   12  2001  2013  12
# 3      31.04    79.30    20.70     2.24   12  2001  2014  13
# 4      15.96   144.10   -44.10   -84.58   12  2001  2015  14
# ...      ...      ...      ...      ...  ...   ...   ...  ..
# 10056   6.86    44.46    55.54    43.99   12  1994  2016  22
# 10057   9.22    43.35    56.65    43.02   12  1994  2017  23
# 10058   8.82    46.23    53.77    40.99   12  1994  2018  24
# 10059   5.61    62.14    37.86    27.35   12  1994  2019  25
# 10060   6.72    56.12    43.88    34.63   12  1994  2020  26
#
# [10061 rows x 59 columns]

# %%
df_con.to_csv("./데이터자료/2. 연결개별통합.csv",index=False)
