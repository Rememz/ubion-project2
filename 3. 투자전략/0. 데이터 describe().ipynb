# %%
import pandas as pd
import numpy as np
import FinanceDataReader as fdr

# %%
backtest_all=pd.read_csv("./데이터/일일주식데이터.csv",encoding='cp949',index_col=0)
data = pd.read_csv("./데이터/5. label 지정 완료.csv", encoding='cp949')
feature = pd.read_csv("./데이터/8-2. Std feature.csv")
data
# Out:
#            회사명  거래소코드        회계년도         상장일 상장폐지일  소속코드                 산업명  \
# 0     (주)CMG제약  58820  2011-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 1     (주)CMG제약  58820  2012-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 2     (주)CMG제약  58820  2013-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 3     (주)CMG제약  58820  2014-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# 4     (주)CMG제약  58820  2015-12-01  2001-08-31   NaN     5    의료용 물질 및 의약품 제조업
# ...        ...    ...         ...         ...   ...   ...                 ...
# 9273   흥구석유(주)  24060  2016-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
# 9274   흥구석유(주)  24060  2017-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
# 9275   흥구석유(주)  24060  2018-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
# 9276   흥구석유(주)  24060  2019-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
# 9277   흥구석유(주)  24060  2020-12-01  1994-12-07   NaN     5         도매 및 상품 중개업
#
# ...

# %%
feature
# Out:
#    mda_feature logit_feature lasso_feature ela_feature same_feature
# 0     자기자본구성비율        매출액증가율        총자본증가율     자기자본증가율     자기자본구성비율
# 1      매출액순이익률       유형자산증가율      자기자본순이익률      총자본증가율       자기자본배율
# 2      순운전자본비율       재고자산증가율      총자본사업이익률     매출액순이익률       총자본증가율
# 3     순운전자본회전률      비유동자산증가율       총자본순이익률    자기자본순이익률     매출채권회전기간
# 4      총자본투자효율       유동자산증가율       순운전자본비율    총자본사업이익률      총자본순이익률
# 5     자기자본순이익률          현금비율      유동자산구성비율     총자본순이익률     총자본사업이익률
# 6       총자본증가율    이자보상배율이자비용      자기자본구성비율     순운전자본비율      순운전자본비율
# 7     총자본사업이익률         비유동비율        자기자본배율    자기자본구성비율     순운전자본회전률
# 8       기계투자효율      자기자본구성비율       매출채권회전률      자기자본배율     자기자본순이익률
# 9       1주당순이익        자기자본배율      매출채권회전기간    매출채권회전기간      매출액순이익률
# 10     총자본순이익률       매출채권회전률      순운전자본회전률    순운전자본회전률      매출채권회전률
# 11      자기자본배율      매출채권회전기간       노동소득분배율       부가가치율        부가가치율

# %%
fea = feature["ela_feature"].tolist()
fea
# Out:
# ['자기자본증가율',
#  '총자본증가율',
#  '매출액순이익률',
#  '자기자본순이익률',
#  '총자본사업이익률',
#  '총자본순이익률',
#  '순운전자본비율',
#  '자기자본구성비율',
#  '자기자본배율',
#  '매출채권회전기간',
#  '순운전자본회전률',
#  '부가가치율']

# %%
defalut= data[data["label"]==1]
good = data[data["label"]==0]

# %%
defalut[fea].describe()
# Out:
#            자기자본증가율      총자본증가율      매출액순이익률       자기자본순이익률    총자본사업이익률  \
# count   171.000000  171.000000   171.000000     171.000000  171.000000
# mean     21.399825  -15.067953  -132.366784    -684.768889   -7.889942
# std     343.251318   49.220056   404.350294    7729.038598   16.508869
# min     -99.850000  -94.940000 -4576.530000 -101015.660000  -82.740000
# 25%     -54.780000  -42.585000  -106.760000     -87.540000  -15.300000
# 50%      -4.500000  -22.360000   -34.570000     -24.140000   -6.240000
# 75%       3.375000   -0.220000     0.380000       1.150000    1.670000
# max    4199.030000  342.560000    31.930000     109.320000   27.770000
#
#           총자본순이익률     순운전자본비율    자기자본구성비율       자기자본배율     매출채권회전기간  \
# count  171.000000  171.000000  171.000000   171.000000   171.000000
# mean   -25.578947   -9.131696   40.531696   474.936433   112.825205
# std     40.015362   49.136344   32.287601   858.732747   136.324908
# ...

# %%
good[fea].describe()
# Out:
#            자기자본증가율       총자본증가율       매출액순이익률     자기자본순이익률     총자본사업이익률  \
# count  9107.000000  9107.000000   9107.000000  9107.000000  9107.000000
# mean     12.501902    11.189176    -16.241054    -3.647740     3.308375
# std      52.797990    38.718842    567.426004    53.152482    10.425333
# min     -97.480000   -95.840000 -51285.280000 -2423.790000  -121.710000
# 25%      -1.645000    -2.940000     -4.570000    -6.440000    -0.140000
# 50%       5.700000     5.210000      2.500000     3.990000     3.690000
# 75%      15.610000    16.035000      8.090000    10.780000     8.285000
# max    1615.330000   922.640000  10193.060000   348.190000   104.940000
#
#            총자본순이익률      순운전자본비율     자기자본구성비율        자기자본배율     매출채권회전기간  \
# count  9107.000000  9107.000000  9107.000000   9107.000000  9107.000000
# mean     -0.230797    20.211343    59.234601   1249.459989    73.668087
# std      15.253697    29.014351    20.735952   1593.635936    70.578791
# ...
